# %%
import pandas as pd
import numpy as np

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#Using pandas read_html, I pulled out the table, which is found as the first of three tables on the Wiki page (designated [0]).  

canada_postal = pd.read_html(url)
df = canada_postal[0]

#Next, I removed all rows containing Boroughs that were entitled "Not assigned."
df2 = df[df.Borough != 'Not assigned']
df2
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 45          M1H       Scarborough
# 46          M2H        North York
# 47          M3H        North York
# 48          M4H         East York
# ..          ...               ...
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 114         M7R       Mississauga
# 116         M9R         Etobicoke
# 117         M1S       Scarborough
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 126         M1T       Scarborough
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 135         M1V       Scarborough
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 142         M8V         Etobicoke
# 143         M9V         Etobicoke
# 144         M1W       Scarborough
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 151         M8W         Etobicoke
# 152         M9W         Etobicoke
# 153         M1X       Scarborough
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# 8              Islington Avenue, Humber Valley Village
# 9                                       Malvern, Rouge
# 11                                           Don Mills
# 12                     Parkview Hill, Woodbine Gardens
# 13                            Garden District, Ryerson
# 14                                           Glencairn
# 17   West Deane Park, Princess Gardens, Martin Grov...
# 18              Rouge Hill, Port Union, Highland Creek
# 20                                           Don Mills
# 21                                    Woodbine Heights
# 22                                      St. James Town
# 23                                  Humewood-Cedarvale
# 26   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 27                   Guildwood, Morningside, West Hill
# 30                                         The Beaches
# 31                                         Berczy Park
# 32                                 Caledonia-Fairbanks
# 36                                              Woburn
# 39                                             Leaside
# 40                                  Central Bay Street
# 41                                            Christie
# 45                                           Cedarbrae
# 46                                   Hillcrest Village
# 47     Bathurst Manor, Wilson Heights, Downsview North
# 48                                    Thorncliffe Park
# ..                                                 ...
# 111                  North Toronto West, Lawrence Park
# 112                The Annex, North Midtown, Yorkville
# 113                             Parkdale, Roncesvalles
# 114              Canada Post Gateway Processing Centre
# 116  Kingsview Village, St. Phillips, Martin Grove ...
# 117                                          Agincourt
# 120                                         Davisville
# 121                     University of Toronto, Harbord
# 122                                 Runnymede, Swansea
# 126            Clarks Corners, Tam O'Shanter, Sullivan
# 129                        Moore Park, Summerhill East
# 130          Kensington Market, Chinatown, Grange Park
# 135  Milliken, Agincourt North, Steeles East, L'Amo...
# 138  Summerhill West, Rathnelly, South Hill, Forest...
# 139  CN Tower, King and Spadina, Railway Lands, Har...
# 142       New Toronto, Mimico South, Humber Bay Shores
# 143  South Steeles, Silverstone, Humbergate, Jamest...
# 144                      Steeles West, L'Amoreaux West
# 147                                           Rosedale
# 148                                     Stn A PO Boxes
# 151                             Alderwood, Long Branch
# 152                Northwest, West Humber - Clairville
# 153                                        Upper Rouge
# 156                        St. James Town, Cabbagetown
# 157             First Canadian Place, Underground city
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %%
#Using .shape confirms that the table now has 103 rows & 3 columns
df2.shape
# Out:
# (103, 3)

# %%
#Creating two new columns to represent the appropriate latitude and longitude of each postal code by joining df2 with the .csv file data
df_geo = pd.read_csv("https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv", index_col = 'Postal Code')

df_toronto_final = df2.join(df_geo, on ='Postal Code')
df_toronto_final
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 45          M1H       Scarborough
# 46          M2H        North York
# 47          M3H        North York
# 48          M4H         East York
# ..          ...               ...
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 114         M7R       Mississauga
# 116         M9R         Etobicoke
# 117         M1S       Scarborough
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 126         M1T       Scarborough
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 135         M1V       Scarborough
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 142         M8V         Etobicoke
# 143         M9V         Etobicoke
# 144         M1W       Scarborough
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 151         M8W         Etobicoke
# 152         M9W         Etobicoke
# 153         M1X       Scarborough
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 2                                            Parkwoods  43.753259 -79.329656
# 3                                     Victoria Village  43.725882 -79.315572
# 4                            Regent Park, Harbourfront  43.654260 -79.360636
# 5                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 6          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 8              Islington Avenue, Humber Valley Village  43.667856 -79.532242
# 9                                       Malvern, Rouge  43.806686 -79.194353
# 11                                           Don Mills  43.745906 -79.352188
# 12                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 13                            Garden District, Ryerson  43.657162 -79.378937
# 14                                           Glencairn  43.709577 -79.445073
# 17   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 18              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 20                                           Don Mills  43.725900 -79.340923
# 21                                    Woodbine Heights  43.695344 -79.318389
# 22                                      St. James Town  43.651494 -79.375418
# 23                                  Humewood-Cedarvale  43.693781 -79.428191
# 26   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 27                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 30                                         The Beaches  43.676357 -79.293031
# 31                                         Berczy Park  43.644771 -79.373306
# 32                                 Caledonia-Fairbanks  43.689026 -79.453512
# 36                                              Woburn  43.770992 -79.216917
# 39                                             Leaside  43.709060 -79.363452
# 40                                  Central Bay Street  43.657952 -79.387383
# 41                                            Christie  43.669542 -79.422564
# 45                                           Cedarbrae  43.773136 -79.239476
# 46                                   Hillcrest Village  43.803762 -79.363452
# 47     Bathurst Manor, Wilson Heights, Downsview North  43.754328 -79.442259
# 48                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 111                  North Toronto West, Lawrence Park  43.715383 -79.405678
# 112                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 113                             Parkdale, Roncesvalles  43.648960 -79.456325
# 114              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 116  Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 117                                          Agincourt  43.794200 -79.262029
# 120                                         Davisville  43.704324 -79.388790
# 121                     University of Toronto, Harbord  43.662696 -79.400049
# 122                                 Runnymede, Swansea  43.651571 -79.484450
# 126            Clarks Corners, Tam O'Shanter, Sullivan  43.781638 -79.304302
# 129                        Moore Park, Summerhill East  43.689574 -79.383160
# 130          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 135  Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 138  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 139  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 142       New Toronto, Mimico South, Humber Bay Shores  43.605647 -79.501321
# 143  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 144                      Steeles West, L'Amoreaux West  43.799525 -79.318389
# 147                                           Rosedale  43.679563 -79.377529
# 148                                     Stn A PO Boxes  43.646435 -79.374846
# 151                             Alderwood, Long Branch  43.602414 -79.543484
# 152                Northwest, West Humber - Clairville  43.706748 -79.594054
# 153                                        Upper Rouge  43.836125 -79.205636
# 156                        St. James Town, Cabbagetown  43.667967 -79.367675
# 157             First Canadian Place, Underground city  43.648429 -79.382280
# 160      The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 165                               Church and Wellesley  43.665860 -79.383160
# 168  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 178  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
#The following code is used to import necessary mdoules for plotting/creating a folium map of Toronto:
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
# !pip install folium
import folium

#Next, restricting the boroughs in the table down to only those containing the name "Toronto" 
df_toronto_abbrev = df_toronto_final[df_toronto_final['Borough'].str.contains("Toronto")]
df_toronto_abbrev
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.12.5)
#     Postal Code           Borough  \
# 4           M5A  Downtown Toronto
# 6           M7A  Downtown Toronto
# 13          M5B  Downtown Toronto
# 22          M5C  Downtown Toronto
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 84          M4M      East Toronto
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 102         M4P   Central Toronto
# 103         M5P   Central Toronto
# 104         M6P      West Toronto
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
#
#                                          Neighbourhood   Latitude  Longitude
# 4                            Regent Park, Harbourfront  43.654260 -79.360636
# 6          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# 13                            Garden District, Ryerson  43.657162 -79.378937
# 22                                      St. James Town  43.651494 -79.375418
# 30                                         The Beaches  43.676357 -79.293031
# 31                                         Berczy Park  43.644771 -79.373306
# 40                                  Central Bay Street  43.657952 -79.387383
# 41                                            Christie  43.669542 -79.422564
# 49                            Richmond, Adelaide, King  43.650571 -79.384568
# 50                        Dufferin, Dovercourt Village  43.669005 -79.442259
# 58   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 59                            Little Portugal, Trinity  43.647927 -79.419750
# 66                        The Danforth West, Riverdale  43.679557 -79.352188
# 67            Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 68        Brockton, Parkdale Village, Exhibition Place  43.636847 -79.428191
# 75                      India Bazaar, The Beaches West  43.668999 -79.315572
# 76                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 84                                     Studio District  43.659526 -79.340923
# 93                                       Lawrence Park  43.728020 -79.388790
# 94                                            Roselawn  43.711695 -79.416936
# 102                                   Davisville North  43.712751 -79.390197
# 103    Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 104                      High Park, The Junction South  43.661608 -79.464763
# 111                  North Toronto West, Lawrence Park  43.715383 -79.405678
# 112                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 113                             Parkdale, Roncesvalles  43.648960 -79.456325
# 120                                         Davisville  43.704324 -79.388790
# 121                     University of Toronto, Harbord  43.662696 -79.400049
# 122                                 Runnymede, Swansea  43.651571 -79.484450
# 129                        Moore Park, Summerhill East  43.689574 -79.383160
# 130          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 138  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 139  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 147                                           Rosedale  43.679563 -79.377529
# 148                                     Stn A PO Boxes  43.646435 -79.374846
# 156                        St. James Town, Cabbagetown  43.667967 -79.367675
# 157             First Canadian Place, Underground city  43.648429 -79.382280
# 165                               Church and Wellesley  43.665860 -79.383160
# 168  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %%
#Next, creating a simple folium Map centered on Toronto, which uses the abbreviated Toronoto neighborhoods' latitude/longitude and displays blue markers
map_toronto = folium.Map(location=[43.6532, -79.3832], zoom_start = 10)

for lat, lng, label in zip(df_toronto_abbrev['Latitude'], df_toronto_abbrev['Longitude'], df_toronto_abbrev['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7c49bb733ae44af086ab4a3118669f15%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7c49bb733ae44af086ab4a3118669f15%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7c49bb733ae44af086ab4a3118669f15%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7c49bb733ae44af086ab4a3118669f15%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6532%2C%20-79.3832%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#Next, defining my Foursquare Credentials and using Foursquare to provide useful neighborhood data that will help in later clustering via getNearbyVenues function

import json
import requests
from pandas.io.json import json_normalize

CLIENT_ID = 'Q5O51ZIB0JS3BSS2UYLH3UVZ4OTE125BZR20RBOWFLXCYMKR'
CLIENT_SECRET = 'UIXNLOGLM0X3UJBH4SKY2TUPKZQDMCQILVZ0S5BU505XEA4O'
VERSION = '20180604'
LIMIT = 100 

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):            
        #API Request to Foursquare
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)

        #GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        #Will return all relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

#Checking the size of the Toronto venues that were found -- 1600 -- as well as displaying the first 5 rows:
toronto_venues = getNearbyVenues(names = df_toronto_abbrev['Neighbourhood'], latitudes = df_toronto_abbrev['Latitude'], longitudes = df_toronto_abbrev['Longitude'])

print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1600, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3          Impact Kitchen       43.656369       -79.356980
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3           Restaurant
# 4                  Spa

# %%
#Using one-hot coding to effectively demonstrate the distribution of venues per neighborhood (and displayed below):

toronto_venues.groupby('Neighborhood')

toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood']

fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  Airport  \
# 0                                         Berczy Park     0.000000   0.0000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000   0.0000
# 2   Business reply mail Processing Centre, South C...     0.000000   0.0000
# 3   CN Tower, King and Spadina, Railway Lands, Har...     0.000
   0.000000
# 8                0.000000  0.000000   0.000000
# 9                0.000000  0.000000   0.000000
# 10               0.000000  0.000000   0.000000
# 11               0.000000  0.010000   0.000000
# 12               0.000000  0.000000   0.000000
# 13               0.010000  0.010000   0.000000
# 14               0.000000  0.010000   0.000000
# 15               0.000000  0.000000   0.000000
# 16               0.000000  0.000000   0.000000
# 17               0.046875  0.015625   0.000000
# 18               0.000000  0.000000   0.000000
# 19               0.023810  0.023810   0.000000
# 20               0.000000  0.000000   0.000000
# 21               0.000000  0.000000   0.000000
# 22               0.000000  0.000000   0.000000
# 23               0.000000  0.000000   0.021739
# 24               0.000000  0.000000   0.000000
# 25               0.000000  0.000000   0.000000
# 26               0.000000  0.000000   0.000000
# 27               0.000000  0.000000   0.000000
# 28               0.000000  0.012821   0.000000
# 29               0.000000  0.000000   0.000000
# 30               0.000000  0.000000   0.000000
# 31               0.000000  0.000000   0.000000
# 32               0.066667  0.000000   0.000000
# 33               0.000000  0.000000   0.000000
# 34               0.000000  0.000000   0.000000
# 35               0.000000  0.000000   0.000000
# 36               0.000000  0.010000   0.000000
# 37               0.000000  0.000000   0.000000
#
# [38 rows x 236 columns]

# %%
#Next, displaying the top 5 venues for each neighborhood in order for final preparations for clustering:

num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#           venue  freq
# 0   Coffee Shop  0.09
# 1  Cocktail Bar  0.05
# 2        Bakery  0.05
# 3      Pharmacy  0.03
# 4    Restaurant  0.03
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#             venue  freq
# 0            Café  0.14
# 1     Coffee Shop  0.09
# 2  Breakfast Spot  0.09
# 3             Gym  0.05
# 4   Burrito Place  0.05
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                 venue  freq
# 0  Light Rail Station  0.11
# 1         Pizza Place  0.06
# 2       Auto Workshop  0.06
# 3          Skate Park  0.06
# 4       Burrito Place  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                 venue  freq
# 0      Airport Lounge  0.12
# 1     Airport Service  0.12
# 2    Airport Terminal  0.12
# 3               Plane  0.06
# 4  Airport Food Court  0.06
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.19
# 1                Café  0.05
# 2  Italian Restaurant  0.05
# 3      Sandwich Place  0.05
# 4     Bubble Tea Shop  0.03
#
#
# ----Christie----
#            venue  freq
# 0  Grocery Store  0.27
# 1           Café  0.20
# 2           Park  0.13
# 3     Baby Store  0.07
# 4    Coffee Shop  0.07
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1     Sushi Restaurant  0.06
# 2  Japanese Restaurant  0.06
# 3           Restaurant  0.04
# 4              Gay Bar  0.04
#
#
# ----Commerce Court, Victoria Hotel----
#          venue  freq
# 0  Coffee Shop  0.12
# 1   Restaurant  0.07
# 2         Café  0.06
# 3        Hotel  0.05
# 4          Gym  0.04
#
#
# ----Davisville----
#             venue  freq
# 0     Pizza Place  0.09
# 1  Sandwich Place  0.09
# 2    Dessert Shop  0.09
# 3             Gym  0.06
# 4            Café  0.06
#
#
# ----Davisville North----
#                   venue  freq
# 0                 Hotel  0.25
# 1  Gym / Fitness Center  0.12
# 2     Food & Drink Shop  0.12
# 3      Department Store  0.12
# 4        Sandwich Place  0.12
#
#
# ----Dufferin, Dovercourt Village----
#          venue  freq
# 0     Pharmacy  0.12
# 1       Bakery  0.12
# 2     Bus Stop  0.06
# 3  Supermarket  0.06
# 4         Pool  0.06
#
#
# ----First Canadian Place, Underground city----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.07
# 2                Hotel  0.05
# 3           Restaurant  0.05
# 4  Japanese Restaurant  0.04
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#               venue  freq
# 0              Park  0.25
# 1             Trail  0.25
# 2     Jewelry Store  0.25
# 3  Sushi Restaurant  0.25
# 4       Yoga Studio  0.00
#
#
# ----Garden District, Ryerson----
#                        venue  freq
# 0             Clothing Store  0.09
# 1                Coffee Shop  0.09
# 2             Cosmetics Shop  0.03
# 3  Middle Eastern Restaurant  0.03
# 4            Bubble Tea Shop  0.03
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#          venue  freq
# 0  Coffee Shop  0.12
# 1     Aquarium  0.05
# 2        Hotel  0.04
# 3         Café  0.04
# 4      Brewery  0.03
#
#
# ----High Park, The Junction South----
#                        venue  freq
# 0         Mexican Restaurant  0.08
# 1            Thai Restaurant  0.08
# 2                       Café  0.08
# 3                  Speakeasy  0.04
# 4  Cajun / Creole Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1                  Park  0.10
# 2        Sandwich Place  0.10
# 3    Italian Restaurant  0.05
# 4               Brewery  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                    venue  freq
# 0                   Café  0.08
# 1            Coffee Shop  0.06
# 2     Mexican Restaurant  0.05
# 3  Vietnamese Restaurant  0.05
# 4                    Bar  0.05
#
#
# ----Lawrence Park----
#               venue  freq
# 0              Park  0.25
# 1          Bus Line  0.25
# 2       Swim School  0.25
# 3  Business Service  0.25
# 4       Yoga Studio  0.00
#
#
# ----Little Portugal, Trinity----
#                            venue  freq
# 0                            Bar  0.14
# 1                           Café  0.05
# 2  Vegetarian / Vegan Restaurant  0.05
# 3                     Restaurant  0.05
# 4                    Men's Store  0.05
#
#
# ----North Toronto West, Lawrence Park----
#                 venue  freq
# 0      Clothing Store  0.18
# 1         Coffee Shop  0.12
# 2         Yoga Studio  0.06
# 3  Mexican Restaurant  0.06
# 4                 Spa  0.06
#
#
# ----Parkdale, Roncesvalles----
#                          venue  freq
# 0               Breakfast Spot  0.14
# 1                    Gift Shop  0.14
# 2                Movie Theater  0.07
# 3  Eastern European Restaurant  0.07
# 4                          Bar  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.21
# 1     Sushi Restaurant  0.07
# 2                Diner  0.07
# 3          Yoga Studio  0.03
# 4  Distribution Center  0.03
#
#
# ----Regent Park, Harbourfront----
#             venue  freq
# 0     Coffee Shop  0.17
# 1            Park  0.07
# 2          Bakery  0.07
# 3  Breakfast Spot  0.04
# 4         Theater  0.04
#
#
# ----Richmond, Adelaide, King----
#             venue  freq
# 0     Coffee Shop  0.11
# 1            Café  0.05
# 2      Restaurant  0.04
# 3  Clothing Store  0.03
# 4          Bakery  0.03
#
#
# ----Rosedale----
#                  venue  freq
# 0                 Park  0.50
# 1           Playground  0.25
# 2                Trail  0.25
# 3               Museum  0.00
# 4  Martial Arts School  0.00
#
#
# ----Roselawn----
#             venue  freq
# 0    Home Service   0.5
# 1          Garden   0.5
# 2     Yoga Studio   0.0
# 3     Music Venue   0.0
# 4  Massage Studio   0.0
#
#
# ----Runnymede, Swansea----
#               venue  freq
# 0              Café  0.08
# 1       Coffee Shop  0.08
# 2  Sushi Restaurant  0.06
# 3               Pub  0.06
# 4       Pizza Place  0.06
#
#
# ----St. James Town----
#                  venue  freq
# 0                 Café  0.06
# 1          Coffee Shop  0.06
# 2            Gastropub  0.04
# 3  American Restaurant  0.04
# 4         Cocktail Bar  0.04
#
#
# ----St. James Town, Cabbagetown----
#                 venue  freq
# 0                Café  0.07
# 1              Bakery  0.07
# 2         Coffee Shop  0.07
# 3          Restaurant  0.07
# 4  Italian Restaurant  0.04
#
#
# ----Stn A PO Boxes----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1  Seafood Restaurant  0.04
# 2            Beer Bar  0.03
# 3          Restaurant  0.03
# 4                Café  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1              Brewery  0.05
# 2            Gastropub  0.05
# 3               Bakery  0.05
# 4  American Restaurant  0.05
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                 venue  freq
# 0         Coffee Shop  0.13
# 1         Pizza Place  0.07
# 2                 Pub  0.07
# 3        Liquor Store  0.07
# 4  Light Rail Station  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.10
# 3     Pizza Place  0.05
# 4     Flower Shop  0.05
#
#
# ----The Beaches----
#                venue  freq
# 0  Health Food Store  0.25
# 1              Trail  0.25
# 2                Pub  0.25
# 3        Yoga Studio  0.00
# 4             Museum  0.00
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.19
# 1             Coffee Shop  0.09
# 2      Italian Restaurant  0.07
# 3  Furniture / Home Store  0.05
# 4          Ice Cream Shop  0.05
#
#
# ----Toronto Dominion Centre, Design Exchange----
#          venue  freq
# 0  Coffee Shop  0.11
# 1        Hotel  0.07
# 2         Café  0.06
# 3   Restaurant  0.04
# 4       Bakery  0.03
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.16
# 1               Bakery  0.06
# 2  Japanese Restaurant  0.06
# 3            Bookstore  0.06
# 4                  Bar  0.06

# %%
#Defining a function in order to allow the venues to be sorted
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

#Subsequently, setting up a separate df to display the top 10 venues/neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

#Columns according to n-th top venues:
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

#New df arranging by most common venues per neighborhood:
toronto_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
toronto_neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
   toronto_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

toronto_neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...    Light Rail Station
# 3  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar                Bakery              Pharmacy
# 1        Breakfast Spot           Coffee Shop          Climbing Gym
# 2               Brewery      Recording Studio  Fast Food Restaurant
# 3       Airport Service      Airport Terminal      Sculpture Garden
# 4    Italian Restaurant        Sandwich Place                  Café
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0    Seafood Restaurant              Beer Bar            Restaurant
# 1         Burrito Place            Restaurant    Italian Restaurant
# 2        Farmers Market         Auto Workshop                   Spa
# 3       Harbor / Marina                   Bar   Rental Car Location
# 4          Burger Joint       Bubble Tea Shop           Salad Place
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0           Cheese Shop        Farmers Market                  Beach
# 1               Stadium          Intersection                    Bar
# 2         Burrito Place            Restaurant                Butcher
# 3                 Plane         Boat or Ferry               Boutique
# 4       Thai Restaurant     Indian Restaurant     Falafel Restaurant

# %%
#Setting up to divide the neighborhoods into 5 clusters:
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

#Implementing K-means clustering fit (and installing/importing sklearn package):
# !pip install scikit-learn
import sklearn
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

#Adding Clustering Labels
toronto_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = df_toronto_abbrev

#Merging both df's to add latitude/longitude for each neighborhood -- showing the header for successful confirmation
toronto_merged = toronto_merged.join(toronto_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')
toronto_merged.dropna(axis=0, inplace=True)
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.20.1)
# Requirement already satisfied: numpy>=1.8.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (1.15.4)
# Requirement already satisfied: scipy>=0.13.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from scikit-learn) (1.2.0)

# %%
#Initiating a folium map in order to add the final clustering results, based on top venues
map_clusters = folium.Map(location=[43.6532, -79.3832], zoom_start=10)

#Cluster color scheme:
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

#Successfully added colored markers to the map alongside cluster numbering, based on respective shared, top venues
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    index = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[index-1],
        fill=True,
        fill_color=rainbow[index-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6398e74e678e4cedacf7e087a53b7123%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6398e74e678e4cedacf7e087a53b7123%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6398e74e678e4cedacf7e087a53b7123%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6398e74e678e4cedacf7e087a53b7123%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6532%2C%20-79.3832%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#Looking at the map, the following most common venues define the clustering #'s:

#Label 0 = Coffee Shop/Café
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 4    Downtown Toronto             0.0           Coffee Shop
# 6    Downtown Toronto             0.0           Coffee Shop
# 13   Downtown Toronto             0.0           Coffee Shop
# 22   Downtown Toronto             0.0           Coffee Shop
# 30       East Toronto             0.0                 Trail
# 31   Downtown Toronto             0.0           Coffee Shop
# 40   Downtown Toronto             0.0           Coffee Shop
# 41   Downtown Toronto             0.0         Grocery Store
# 49   Downtown Toronto             0.0           Coffee Shop
# 50       West Toronto             0.0              Pharmacy
# 58   Downtown Toronto             0.0           Coffee Shop
# 59       West Toronto             0.0                   Bar
# 66       East Toronto             0.0      Greek Restaurant
# 67   Downtown Toronto             0.0           Coffee Shop
# 68       West Toronto             0.0                  Café
# 75       East Toronto             0.0                  Park
# 76   Downtown Toronto             0.0           Coffee Shop
# 84       East Toronto             0.0           Coffee Shop
# 102   Central Toronto             0.0                 Hotel
# 104      West Toronto             0.0       Thai Restaurant
# 111   Central Toronto             0.0        Clothing Store
# 112   Central Toronto             0.0        Sandwich Place
# 113      West Toronto             0.0        Breakfast Spot
# 120   Central Toronto             0.0           Pizza Place
# 121  Downtown Toronto             0.0                  Café
# 122      West Toronto             0.0                  Café
# 130  Downtown Toronto             0.0                  Café
# 138   Central Toronto             0.0           Coffee Shop
# 139  Downtown Toronto             0.0        Airport Lounge
# 148  Downtown Toronto             0.0           Coffee Shop
# 156  Downtown Toronto             0.0           Coffee Shop
# 157  Downtown Toronto             0.0           Coffee Shop
# 165  Downtown Toronto             0.0           Coffee Shop
# 168      East Toronto             0.0    Light Rail Station
#
#     2nd Most Common Venue 3rd Most Common Venue  \
# 4                    Park                Bakery
# 6        Sushi Restaurant                 Diner
# 13         Clothing Store        Cosmetics Shop
# 22                   Café             Gastropub
# 30      Health Food Store                   Pub
# 31           Cocktail Bar                Bakery
# 40     Italian Restaurant        Sandwich Place
# 41                   Café                  Park
# 49                   Café            Restaurant
# 50                 Bakery           Music Venue
# 58               Aquarium                 Hotel
# 59            Men's Store            Restaurant
# 66            Coffee Shop    Italian Restaurant
# 67                  Hotel                  Café
# 68         Breakfast Spot           Coffee Shop
# 75         Sandwich Place  Fast Food Restaurant
# 76             Restaurant                  Café
# 84                Brewery             Gastropub
# 102      Department Store                  Park
# 104    Mexican Restaurant                  Café
# 111           Coffee Shop   Sporting Goods Shop
# 112                  Café           Coffee Shop
# 113             Gift Shop          Dessert Shop
# 120        Sandwich Place          Dessert Shop
# 121             Bookstore                   Bar
# 122           Coffee Shop                   Pub
# 130           Coffee Shop    Mexican Restaurant
# 138                   Pub   Fried Chicken Joint
# 139       Airport Service      Airport Terminal
# 148    Seafood Restaurant          Cocktail Bar
# 156                Bakery            Restaurant
# 157                  Café            Restaurant
# 165   Japanese Restaurant      Sushi Restaurant
# 168               Brewery      Recording Studio
#
#              4th Most Common Venue          5th Most Common Venue  \
# 4                   Breakfast Spot                        Theater
# 6                   Sandwich Place                           Park
# 13                            Café             Italian Restaurant
# 22             American Restaurant                   Cocktail Bar
# 30                       Wine Shop               Doner Restaurant
# 31                        Pharmacy             Seafood Restaurant
# 40                            Café                   Burger Joint
# 41                      Restaurant                     Baby Store
# 49                             Gym                          Hotel
# 50                            Bank      Middle Eastern Restaurant
# 58                            Café            Fried Chicken Joint
# 59   Vegetarian / Vegan Restaurant                           Café
# 66          Furniture / Home Store                 Ice Cream Shop
# 67                      Restaurant                    Salad Place
# 68                    Climbing Gym                  Burrito Place
# 75                             Gym                     Board Shop
# 76                           Hotel            American Restaurant
# 84                            Café                         Bakery
# 102           Gym / Fitness Center                 Breakfast Spot
# 104      Cajun / Creole Restaurant             Italian Restaurant
# 111           Fast Food Restaurant             Mexican Restaurant
# 112                            Pub                    Cheese Shop
# 113               Cuban Restaurant    Eastern European Restaurant
# 120                            Gym             Italian Restaurant
# 121            Japanese Restaurant                         Bakery
# 122               Sushi Restaurant                    Pizza Place
# 130          Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 138                   Liquor Store                 Sandwich Place
# 139               Sculpture Garden                Harbor / Marina
# 148                     Restaurant                         Bakery
# 156                           Café             Italian Restaurant
# 157                          Hotel            Japanese Restaurant
# 165                     Restaurant                        Gay Bar
# 168           Fast Food Restaurant                 Farmers Market
#
#          6th Most Common Venue 7th Most Common Venue  \
# 4                          Pub                  Café
# 6           Mexican Restaurant   Japanese Restaurant
# 13   Middle Eastern Restaurant   Japanese Restaurant
# 22                         Gym        Lingerie Store
# 30                       Diner        Discount Store
# 31                    Beer Bar            Restaurant
# 40             Bubble Tea Shop           Salad Place
# 41                 Coffee Shop           Candy Store
# 49                      Bakery        Clothing Store
# 50                        Café              Bus Stop
# 58                  Restaurant               Brewery
# 59            Asian Restaurant    Miscellaneous Shop
# 66                Dessert Shop               Brewery
# 67          Italian Restaurant                Bakery
# 68                  Restaurant    Italian Restaurant
# 75                     Brewery            Restaurant
# 76          Italian Restaurant                   Gym
# 84         American Restaurant           Yoga Studio
# 102             Sandwich Place     Food & Drink Shop
# 104        Fried Chicken Joint                   Bar
# 111                      Diner                  Park
# 112               Liquor Store             BBQ Joint
# 113                    Dog Run    Italian Restaurant
# 120                       Café      Sushi Restaurant
# 121                        Pub          Dessert Shop
# 122         Italian Restaurant                   Gym
# 130                        Bar        Farmers Market
# 138                 Restaurant                  Bank
# 139                        Bar   Rental Car Location
# 148                   Beer Bar   Japanese Restaurant
# 156                       Park             Pet Store
# 157                        Gym            Steakhouse
# 165                        Pub           Men's Store
# 168              Auto Workshop                   Spa
#
#          8th Most Common Venue 9th Most Common Venue  \
# 4               Farmers Market     French Restaurant
# 6           Italian Restaurant   Fried Chicken Joint
# 13             Bubble Tea Shop                 Hotel
# 22              Farmers Market    Seafood Restaurant
# 30         Distribution Center               Dog Run
# 31                 Cheese Shop        Farmers Market
# 40             Thai Restaurant     Indian Restaurant
# 41                   Nightclub    Italian Restaurant
# 49             Thai Restaurant         Deli / Bodega
# 50                        Pool                   Bar
# 58         Sporting Goods Shop        Scenic Lookout
# 59                 Record Shop           Pizza Place
# 66             Bubble Tea Shop            Restaurant
# 67         American Restaurant   Japanese Restaurant
# 68                     Stadium          Intersection
# 75                         Pub           Pizza Place
# 76               Deli / Bodega   Japanese Restaurant
# 84             Coworking Space           Cheese Shop
# 102                    Dog Run        Discount Store
# 104     Furniture / Home Store   Arts & Crafts Store
# 111         Chinese Restaurant                  Café
# 112  Middle Eastern Restaurant           Flower Shop
# 113                        Bar            Restaurant
# 120                Coffee Shop      Toy / Game Store
# 121                 Restaurant        Sandwich Place
# 122               Gourmet Shop            Restaurant
# 130                     Bakery         Grocery Store
# 138                Supermarket            Bagel Shop
# 139                      Plane         Boat or Ferry
# 148         Italian Restaurant                  Café
# 156                   Pharmacy           Pizza Place
# 157                Salad Place   American Restaurant
# 165   Mediterranean Restaurant                 Hotel
# 168              Burrito Place            Restaurant
#
#         10th Most Common Venue
# 4         Gym / Fitness Center
# 6          Distribution Center
# 13               Movie Theater
# 22              Cosmetics Shop
# 30         Dumpling Restaurant
# 31                       Beach
# 40          Falafel Restaurant
# 41         Distribution Center
# 49            Asian Restaurant
# 50                 Supermarket
# 58          Italian Restaurant
# 59                Cocktail Bar
# 66                        Café
# 67          Seafood Restaurant
# 68                         Bar
# 75               Movie Theater
# 76          Seafood Restaurant
# 84              Clothing Store
# 102        Distribution Center
# 104                Flea Market
# 111                 Restaurant
# 112             History Museum
# 113              Movie Theater
# 120          Indian Restaurant
# 121           Sushi Restaurant
# 122  Latin American Restaurant
# 130                       Park
# 138           Sushi Restaurant
# 139                   Boutique
# 148                        Gym
# 156                        Pub
# 157           Asian Restaurant
# 165       Fast Food Restaurant
# 168                    Butcher

# %%
#Label 1 = Park/Playground
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 147  Downtown Toronto             1.0                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 147            Playground                 Trail             Wine Shop
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 147      Department Store           Escape Room     Electronics Store
#
#            8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 147  Eastern European Restaurant   Dumpling Restaurant             Donut Shop

# %%
#Label 2 = Home Service
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 94  Central Toronto             2.0          Home Service
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 94                Garden             Wine Shop      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 94  Ethiopian Restaurant           Escape Room     Electronics Store
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 94  Eastern European Restaurant   Dumpling Restaurant             Donut Shop

# %%
#Label 3 = Park/Trail
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 103  Central Toronto             3.0                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 103                 Trail         Jewelry Store      Sushi Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 103             Wine Shop          Dessert Shop           Escape Room
#
#     8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 103     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %%
#Label 4 = Business Service
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 93  Central Toronto             4.0      Business Service
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 93                  Park              Bus Line           Swim School
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 93             Wine Shop           Escape Room     Electronics Store
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 93  Eastern European Restaurant   Dumpling Restaurant             Donut Shop
